# %%
from scipy.io import netcdf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import netCDF4 as nc
import matplotlib as mpl
import xarray as xr
import geopandas as gpd

# %%
#script ini digunakan untuk melakukan re-gridding menjadi 0.50 derajat

# %%
ds = xr.open_dataset("/Users/roniabuhanif/Downloads/BMKG/data_skripsi/data_bu_azizah/ch4/ch4.nc") #membukan file .nc yang diperlukan
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 6, latitude: 4, time: 60)
# Coordinates:
#   * longitude  (longitude) float32 110.9 111.6 112.4 113.1 113.9 114.6
#   * latitude   (latitude) float32 -6.66 -7.41 -8.16 -8.91
#   * time       (time) datetime64[ns] 2016-01-01 2016-02-01 ... 2020-12-01
# Data variables:
#     ch4        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-12-20 16:35:53 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
latii = [-6.294]
lonii = [110.915]

# %%
# menentukan longitude baru
# menentukan latitude baru
new_lon = np.arange(ds.longitude[0], ds.longitude[-1], 0.05)  # 0.4 to 0.05
new_lat = np.arange(ds.latitude[-1], ds.latitude[0], 0.05)
# melakukan re-gridding menggunakan interpolation
ds = ds.interp(latitude=new_lat, longitude=new_lon)

# %%
import math

# %%
# mengubah data menjadi data tipe dataframa
df = ds.to_dataframe()
# konversi kg/kg menjadi ppm
# 1. kg/kg to ppb = divided by 1x10^-9
# 2. ppb to ppm = multiply by 0.001
df ["ch4"] = (df["ch4"]/0.000000001)*0.001
# menyimpan dataframe menjadi .csv
df.to_csv("ch4_satuan.csv")

# %%
import geopandas as gpd
import pandas as pd

# %%
# Load shapefile into a GeoDataFrame
gdf_shapefile = gpd.read_file('/Users/roniabuhanif/Downloads/BMKG/data_skripsi/peta_jatim/kabupaten.shp')

# %%
gdf_shapefile.crs

# %%
gdf_shapefile.head(5)
# Out:
#     IDKABKOTA  COUNT  urutan_kab  KEPADATAN  SEXRATIO    TFR    CBR    CPR  \
# 0   BANGKALAN    283          26        696     91.48  1.819  12.42  36.66
# 1  BANYUWANGI    227          10        432     99.08  2.077  14.29  61.76
# 2        BATU     24          38        942    101.28  2.119  14.59  69.07
# 3  BOJONEGORO    432          22        523     97.83  1.891  12.94  73.54
# 4   BONDOWOSO    211          11        469     94.97  1.997  13.71  67.03
#
#    ALH3PLUS    UKP  ...    KS1  PRAKS_KS1    IPM  JAMBANSEP  SAKIT  AIRBERSIH  \
# 0     35.01  18.64  ...  35.20      58.39  64.52      25.68  17.93      97.22
# 1     25.89  19.27  ...  20.89      41.69  68.81      54.49  32.71      88.68
# 2     20.81  20.50  ...  18.29      29.86  74.35      78.21  39.54      99.18
# 3     21.09  18.95  ...  16.59      68.66  66.84      40.79  24.11      95.85
# 4     21.92  17.08  ...  22.44      64.54  62.79      22.12  33.68      88.40
#
#     LPP  ASFR_20_24  ASFR                                           geometry
# 0  1.21        None  None  POLYGON ((112.68201 -7.08612, 112.68037 -7.083...
# 1  0.45        None  None  MULTIPOLYGON (((113.90852 -8.58587, 113.90841 ...
# 2  1.25        None  None  POLYGON ((112.48183 -7.86983, 112.48473 -7.867...
# 3  0.38        None  None  POLYGON ((112.07846 -7.35360, 112.08035 -7.358...
# 4  0.68        None  None  POLYGON ((114.06098 -8.12161, 114.05655 -8.125...
#
# [5 rows x 28 columns]

# %%
# Load CSV
df_csv = pd.read_csv('co2_satuan.csv')

# %%
df_csv.head(54000)
# Out:
#              time  latitude   longitude         co2
# 0      2016-01-01     -8.88  110.910004  610.471237
# 1      2016-01-01     -8.88  110.960004  610.641677
# 2      2016-01-01     -8.88  111.010004  610.812117
# 3      2016-01-01     -8.88  111.060004  610.982557
# 4      2016-01-01     -8.88  111.110004  611.152997
# ...           ...       ...         ...         ...
# 53995  2017-04-01     -6.68  114.410004  609.816734
# 53996  2017-04-01     -6.68  114.460004  609.790856
# 53997  2017-04-01     -6.68  114.510004  609.764979
# 53998  2017-04-01     -6.68  114.560004  609.739102
# 53999  2017-04-01     -6.68  114.610004  609.713224
#
# [54000 rows x 4 columns]

# %% [markdown]
# sampai sini

# %%
# Convert DataFrame to GeoDataFrame
geometry = gpd.points_from_xy(df_csv['longitude'], df_csv['latitude'])
gdf_csv = gpd.GeoDataFrame(df_csv, geometry=geometry)

# %%
# spatial join
result = gpd.sjoin(gdf_shapefile, gdf_csv, how='inner', predicate='within')
dissolved_result = result.dissolve(by= 'IDKABKOTA', aggfunc=['min', 'max', 'mean'])
dissolved_result
# Out:
# Empty GeoDataFrame
# Columns: [geometry, (COUNT, min), (COUNT, max), (COUNT, mean), (urutan_kab, min), (urutan_kab, max), (urutan_kab, mean), (KEPADATAN, min), (KEPADATAN, max), (KEPADATAN, mean), (SEXRATIO, min), (SEXRATIO, max), (SEXRATIO, mean), (TFR, min), (TFR, max), (TFR, mean), (CBR, min), (CBR, max), (CBR, mean), (CPR, min), (CPR, max), (CPR, mean), (ALH3PLUS, min), (ALH3PLUS, max), (ALH3PLUS, mean), (UKP, min), (UKP, max), (UKP, mean), (NIKAHDINI, min), (NIKAHDINI, max), (NIKAHDINI, mean), (IMR, min), (IMR, max), (IMR, mean), (AHH, min), (AHH, max), (AHH, mean), (BUTAHURUF, min), (BUTAHURUF, max), (BUTAHURUF, mean), (EKONOMI, min), (EKONOMI, max), (EKONOMI, mean), (TPT, min), (TPT, max), (TPT, mean), (TPAK, min), (TPAK, max), (TPAK, mean), (PRAKS, min), (PRAKS, max), (PRAKS, mean), (KS1, min), (KS1, max), (KS1, mean), (PRAKS_KS1, min), (PRAKS_KS1, max), (PRAKS_KS1, mean), (IPM, min), (IPM, max), (IPM, mean), (JAMBANSEP, min), (JAMBANSEP, max), (JAMBANSEP, mean), (SAKIT, min), (SAKIT, max), (SAKIT, mean), (AIRBERSIH, min), (AIRBERSIH, max), (AIRBERSIH, mean), (LPP, min), (LPP, max), (LPP, mean), (ASFR_20_24, min), (ASFR_20_24, max), (ASFR_20_24, mean), (ASFR, min), (ASFR, max), (ASFR, mean), (index_right, min), (index_right, max), (index_right, mean), (time, min), (time, max), (time, mean), (latitude, min), (latitude, max), (latitude, mean), (longitude, min), (longitude, max), (longitude, mean), (co2, min), (co2, max), (co2, mean)]
# Index: []
#
# [0 rows x 94 columns]
